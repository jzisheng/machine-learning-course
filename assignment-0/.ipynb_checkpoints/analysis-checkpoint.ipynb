# %%
import pandas as pd

# %% [markdown]
# ## 1. Dataset

# %%
df = pd.read_csv('uber-raw-data-apr14.csv')

# %% [markdown]
# ## 2. Dataset Description
# Using a Jupyter notebook, describe the dataset, the [source](https://www.kaggle.com/fivethirtyeight/uber-pickups-in-new-york-city) of the data, and the reason the dataset was of interest.
#
# >The dataset comes from [Fivethirtyeight](https://www.kaggle.com/fivethirtyeight/uber-pickups-in-new-york-city), obtained from a FOIA request for for hire vehicle pickups. While there are mutliple CSV files, I only choose the raw data from Uber for the month of April, 2014. Each row contains information on the latitude, longitude, and time of pickup. The motivation for this dataset is to explore traffic patterns, and Uber's presence in NYC.

# %%
df.head(3)
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512

# %% [markdown]
# ## 3. Plot the Data
# Check the data and see if they need to be cleaned: are there missing values? Are there clearly erroneous values? Do two tables need to be merged together? Clean the data so it can be visualized.

# %% [markdown]
# >In this dataset, there are no missing values. I did not observe any erroneous values, and as I am only working with one table, multiple tables do not need to be merged.

# %%
df.isnull().sum()
# Out:
# Date/Time    0
# Lat          0
# Lon          0
# Base         0
# dtype: int64

# %% [markdown]
# Observe that there are a total of 564516 rows

# %%
len(df)
# Out:
# 564516

# %% [markdown]
# First have to convert the 'Date/Time' column into a `datetime` object in order to make any observations

# %%
import seaborn as sns
import folium
from folium import plugins
from folium.plugins import HeatMap
from datetime import datetime
import matplotlib as plt

# %%
df['datetime'] = df['Date/Time'].apply(lambda x: datetime.strptime(x,'%m/%d/%Y %H:%M:%S'))

# %%
df['hour'] = df['datetime'].apply(lambda x: x.hour)
df['weekday'] = df['datetime'].apply(lambda x: x.weekday())

# %% [markdown]
# Below is a graph of the hour vs. count of pickups

# %%
ax = sns.countplot(x='hour',data=df,color='grey')

# %% [markdown]
# Below is a graph of the day of the week vs. count of pickups

# %%
ax = sns.countplot(x='weekday',data=df,color='grey')

# %% [markdown]
# Then I explored the location of Uber pickups in NYC using Folium. Note that I was only able to map 50,000 points - anything more and Folium crashed.

# %%
hmap = folium.Map(location=[40.769, -73.9549], zoom_start=10, )

hm_wide = HeatMap( list(zip(df.Lat.values[:50000],(df.Lon.values[:50000]))), 
                   min_opacity=0.2,
                   max_val=100,
                   radius=17, blur=15, 
                   max_zoom=1, 
                 )
#folium.GeoJson(district23).add_to(hmap)
hmap.add_child(hm_wide)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4. Insights
# What insights are you able to take away from exploring the data? Is there a reason why analyzing the dataset you chose is particularly interesting or important? Summarize this as if your target audience was the readership of a major news organization - boil down your findings in a way that is accessible, but still accurate.
#
# >Insights I gathered from this dataset was the busiest weekdays for Uber in April 2014 were Wednesdays, then Tuesdays, and Fridays. The busiest hours were afternoon rush hour, and then morning rush hour. Peak rush hour in the morning was 7 AM, and in the afternoons 5 PM.
#
# >I also explored the pickup locations of Uber in NYC, and discovered that Uber's presence in the northeast is much larger than I thought: with pickups occuring in Long Island, New Haven CT, and Trenton NJ. Aside from this, there are obvious hubs of activity on Newark, Laguardia, and JFK Airport. It should be noted that I was not able to make a heatmap of the entire dataset, as it was too many points for the heatmap.
